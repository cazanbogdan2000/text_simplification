# %%
# #**Add python version you wish** to list
# !sudo apt-get update -y
# !sudo apt-get install python3.8
# from IPython.display import clear_output
# clear_output()
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1

# # Choose one of the given alternatives:
# !sudo update-alternatives --config python3

# # This one used to work but now NOT(for me)!
# # !sudo update-alternatives --config python

# # Check the result
# !python3 --version

# # Attention: Install pip (... needed!)
# !sudo apt install python3-pip

# %%
# !pip install sentencepiece -q
# !pip install transformers -q
# !pip install torch -q
# !pip install datasets -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 34.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 19.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 28.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 23.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.6 MB/s eta 0:00:00
# ...

# %%
import os
import torch
import numpy as np
import pandas as pd
import torch.nn.functional as F

from transformers import T5Tokenizer, T5ForConditionalGeneration
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler

# %%
# Setting up the device for GPU usage
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
from datasets import load_dataset
dataset = load_dataset('bogdancazan/news-not-not-ela-text-simplification')
# Out:
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/bogdancazan___csv/bogdancazan--news-not-not-ela-text-simplification-cdb0ef56704f4c59/0.0.0/eea64c71ca8b46dd3f537ed218fc9bf495d5707789152eb2764f5c78fa66d59d)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Normal', 'Simple'],
#         num_rows: 102711
#     })
#     test: Dataset({
#         features: ['Normal', 'Simple'],
#         num_rows: 1414
#     })
# })

# %%
# !git clone https://github.com/feralvam/easse.git && cd easse && pip install .
# Out:
# Cloning into 'easse'...
# remote: Enumerating objects: 1960, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 1960 (delta 107), reused 95 (delta 95), pack-reused 1827
# Receiving objects: 100% (1960/1960), 33.14 MiB | 9.71 MiB/s, done.
# Resolving deltas: 100% (1229/1229), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/easse
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/facebookresearch/text-simplification-evaluation.git (to revision main) to /tmp/pip-install-w621fxd9/tseval_9c7f058b64494f7ebf004d7a731a3b4f
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/text-simplification-evaluation.git /tmp/pip-install-w621fxd9/tseval_9c7f058b64494f7ebf004d7a731a3b4f
# ...

# %%
# !cd easse && pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/easse
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/facebookresearch/text-simplification-evaluation.git (to revision main) to /tmp/pip-install-sm5b_j82/tseval_b22121b789a24e149898d948e3f442b0
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/text-simplification-evaluation.git /tmp/pip-install-sm5b_j82/tseval_b22121b789a24e149898d948e3f442b0
#   Resolved https://github.com/facebookresearch/text-simplification-evaluation.git to commit f335e2e27026321c7c3d1dd63857416c7e7397b2
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for easse: filename=easse-0.2.4-py3-none-any.whl size=5318561 sha256=a7aadc584d3549aef0263249ebd70b36c4e004416dc6a4cf68a49b28308cf062
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s7glzhx9/wheels/a7/c7/f7/b94a747d4c5740f01e294a94eaaaf173f0d2666a35505170d7
# ...

# %%
pred = pd.read_csv('predictions.csv')
pred.rename(columns={"Normal": "Reff"})
# Out:
#       Unnamed: 0                                               Reff  \
# 0              0  when the kernel is heated above degrees celsiu...
# 1              1  when the kernel is heated above degrees celsiu...
# 2              2  when the kernel is heated above degrees celsiu...
# 3              3  when the kernel gets very hot and the water in...
# 4              4  when the kernel gets very hot above degrees ce...
# ...          ...                                                ...
# 1409        1409  this week u.s. ambassador to colombia kevin wh...
# 1410        1410  and the country is on track to produce tons th...
# 1411        1411  colombian land dedicated to avocado production...
# 1412        1412   but tons is n t enough he said looking forwar...
# 1413        1413   but tons is n t enough iragorri said looking ...
#
#                                                  Simple  \
# 0     when the kernel gets very hot and the water in...
# ...

# %%
test_dataset =  dataset['test']
test_dataset
# Out:
# Dataset({
#     features: ['Normal', 'Simple'],
#     num_rows: 1414
# })

# %%
pred['Src'] = test_dataset['Normal']

# %%
pred
# Out:
#       Unnamed: 0                                             Normal  \
# 0              0  when the kernel is heated above degrees celsiu...
# 1              1  when the kernel is heated above degrees celsiu...
# 2              2  when the kernel is heated above degrees celsiu...
# 3              3  when the kernel gets very hot and the water in...
# 4              4  when the kernel gets very hot above degrees ce...
# ...          ...                                                ...
# 1409        1409  this week u.s. ambassador to colombia kevin wh...
# 1410        1410  and the country is on track to produce tons th...
# 1411        1411  colombian land dedicated to avocado production...
# 1412        1412   but tons is n t enough he said looking forwar...
# 1413        1413   but tons is n t enough iragorri said looking ...
#
#                                                  Simple  \
# 0     when the kernel gets very hot and the water in...
# ...

# %%
count = 0
for index, row in pred.iterrows():
    # Access individual values in the row
    if row['Generated'] == row['Src']:
      count+=1

count
# Out:
# 39

# %%
pred.to_csv('predictions.csv', index=False)

# Download the CSV file
from google.colab import files
files.download('predictions.csv')

# %%
# !cd ./easse

# %%
# !ls
# Out:
# easse  predictions.csv	sample_data

# %%
from easse.sari import corpus_sari

eval = pd.DataFrame()
eval['sari']=[corpus_sari(orig_sents=test_dataset['Normal'],
            sys_sents=pred['Generated'],
            refs_sents=[test_dataset['Simple']])]
eval
# Out:
#         sari
# 0  35.986139

# %%
# !pip install sacrebleu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sacrebleu import corpus_bleu

eval['bleu']=corpus_bleu(pred['Generated'].tolist(), [test_dataset['Simple']]).score
eval
# Out:
#         sari       bleu
# 0  35.986139  19.210133

# %%
# !pip install textstat
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 38.6 MB/s eta 0:00:00
# ...

# %%
from textstat import flesch_kincaid_grade

# %%
fkgl_scores = [flesch_kincaid_grade(text) for text in pred['Generated']]
eval['fkgl'] = sum(fkgl_scores) / len(fkgl_scores)

# %%
eval
# Out:
#         sari       bleu       fkgl
# 0  35.986139  19.210133  11.574399
